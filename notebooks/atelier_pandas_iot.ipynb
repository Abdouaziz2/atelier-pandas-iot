# %% [markdown]
# **Partie 1 — Series**
# 1. Qu'est-ce qu'une Series ?
#
# Une Series Pandas est une structure de données unidimensionnelle avec un index.
#
# Tu peux la voir comme :
#
# index     valeur
#
#   0        24.5
#
#   1        25.1
#
#
# Elle possède donc principalement :
#
# des valeurs
# un index
#
# Pandas permet de créer une Series avec :
#
# pd.Series(...)
#
# Avant de commencer, importe Pandas :
#
# import pandas as pd

# %%
import pandas as pd

temperatures = pd.Series([24.5, 25.1, 26.3, 27.0])

temperatures
# Out:
# 0    24.5
# 1    25.1
# 2    26.3
# 3    27.0
# dtype: float64

# %% [markdown]
# **Concept :** pd.Series() crée une structure de données unidimensionnelle composée de valeurs associées à un index.
#
# Par défaut, Pandas crée automatiquement l'index :
#
# 0, 1, 2, 3
# ### 2. Afficher son index

# %%
temperatures.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# .index permet d'accéder à l'index de la Series.
#
# Ici :
#
# start=0 → l'index commence à 0 ;
# stop=4 → s'arrête avant 4 ;
# step=1 → avance de 1.
# ### 3. Afficher la 1ère valeur

# %%
temperatures.iloc[0]
# Out:
# np.float64(24.5)

# %% [markdown]
# .iloc[] sélectionne une valeur selon sa position.
#
# iloc[0] → première position
#
# iloc[1] → deuxième position
#
# ### 4. Afficher la dernière valeur

# %%
temperatures.iloc[-1]
# Out:
# np.float64(27.0)

# %% [markdown]
# ### 5. Créer, de deux façons différentes, une Series de 4 températures avec les heures comme index
#
# **Les heures demandées sont :**
#
# 12h, 13h, 14h, 15h
#
# **Méthode 1 — avec index=**

# %%
temperatures_heures = pd.Series(
    [24.5, 25.1, 26.3, 27.0],
    index=["12h", "13h", "14h", "15h"]
)

temperatures_heures
# Out:
# 12h    24.5
# 13h    25.1
# 14h    26.3
# 15h    27.0
# dtype: float64

# %% [markdown]
# Ici, on fournit séparément :
#
# values = [24.5, 25.1, 26.3, 27.0]
# index = ["12h", "13h", "14h", "15h"]
#
# **Méthode 2 — avec un dictionnaire**

# %%
temperatures_heures = pd.Series({
    "12h": 24.5,
    "13h": 25.1,
    "14h": 26.3,
    "15h": 27.0
})

temperatures_heures
# Out:
# 12h    24.5
# 13h    25.1
# 14h    26.3
# 15h    27.0
# dtype: float64

# %% [markdown]
# Ici, Pandas utilise directement :
#
# clé        → index
#
# valeur     → donnée
#
# ### 6. Afficher la 1ère et la dernière valeur

# %%
premiere = temperatures_heures.iloc[0]
derniere = temperatures_heures.iloc[-1]

premiere, derniere
# Out:
# (np.float64(24.5), np.float64(27.0))

# %% [markdown]
# **Pourquoi iloc ici ?**
#
# Même si notre index contient maintenant "12h", "13h", etc., la question demande la première et la dernière valeur, donc on travaille avec leur position :
#
# temperatures_heures.iloc[0]   # première
# temperatures_heures.iloc[-1]  # dernière
#
# À l'inverse, si on voulait précisément la température de 12h, on pourrait utiliser le label :
#
# temperatures_heures["12h"]
#
# On approfondira cette différence avec loc / iloc à la question 4 de l'atelier.

# %% [markdown]
# # Partie 2 – DataFrame
#
# Un DataFrame est une structure de données bidimensionnelle, organisée en lignes et colonnes.
# On peut le comparer à un tableau Excel :
# un dataframe se comporte comme un dictionnaire dont les clefs sont les noms des colonnes et les valeurs sont des séries.
# on peut le créer à partir d'une array numpy (mais ce n'est pas très pratique et le type des données est le même pour toutes les colonnes, ici float64)
# 1) Créer et afficher le dataframe df_test à partir du dictionnaire suivant

# %%
data = {
"capteur": ["C001", "C002", "C003"],
"temperature": [24.5, 25.1, 26.3],
"humidite": [65, 67, 70]
}
df_test = pd.DataFrame(data)
df_test
# Out:
#   capteur  temperature  humidite
# 0    C001         24.5        65
# 1    C002         25.1        67
# 2    C003         26.3        70

# %% [markdown]
# **2) Importer le dataset mesures_capteurs.csv dans le dataframe df**

# %%
df = pd.read_csv("../data/mesures_capteurs.csv")

df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
# ..        ...                  ...        ...      ...          ...       ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67     60.28
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34     61.42
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73     63.49
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83     79.77
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02     52.04
#
#      pression  consommation etat
# ...

# %% [markdown]
# **3) Afficher les dimensions de df**

# %%
df.shape
# Out:
# (605, 9)

# %% [markdown]
# # Partie 3 – Exploration
#
# **1) Afficher les premières lignes**

# %%
df.head()
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK

# %% [markdown]
# **2) Afficher les 10 premières lignes**

# %%
df.head(10)
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
# 5     M0595  2026-01-29 18:00:00       C007     B003        24.51     58.01
# 6     M0011  2026-01-05 10:00:00       C011     B004        29.23     70.43
# 7     M0132  2026-01-10 11:00:00       C012     B004        31.21     60.57
# 8     M0444  2026-01-23 11:00:00       C012     B004        23.11     82.06
# 9     M0087  2026-01-08 14:00:00       C003     B001        28.85     44.37
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# ...

# %% [markdown]
# 3) Afficher les dernières lignes

# %%
df.tail()
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67     60.28
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34     61.42
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73     63.49
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83     79.77
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02     52.04
#
#      pression  consommation etat
# 600   1015.11        282.36   OK
# 601   1019.43        357.43   OK
# 602   1016.46        152.79   OK
# 603   1017.05        170.97   OK
# 604   1001.14         44.99   OK

# %% [markdown]
# **4) Afficher le nombre de lignes**

# %%
df.shape[0]
# Out:
# 605

# %% [markdown]
# 5) Afficher le nombre de colonnes

# %%
df.shape[1]
# Out:
# 9

# %% [markdown]
# 6) Afficher les noms des colonnes

# %%
df.columns
# Out:
# Index(['id_mesure', 'date_heure', 'id_capteur', 'batiment', 'temperature',
#        'humidite', 'pression', 'consommation', 'etat'],
#       dtype='str')

# %% [markdown]
# 7) Afficher les informations générales

# %%
df.columns.tolist()
# Out:
# ['id_mesure',
#  'date_heure',
#  'id_capteur',
#  'batiment',
#  'temperature',
#  'humidite',
#  'pression',
#  'consommation',
#  'etat']

# %% [markdown]
# **7) Afficher les informations générales**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_mesure     605 non-null    str
#  1   date_heure    605 non-null    str
#  2   id_capteur    605 non-null    str
#  3   batiment      605 non-null    str
#  4   temperature   599 non-null    float64
#  5   humidite      600 non-null    float64
#  6   pression      600 non-null    float64
#  7   consommation  600 non-null    float64
#  8   etat          601 non-null    str
# dtypes: float64(4), str(5)
# memory usage: 42.7 KB

# %% [markdown]
# **8) Afficher les statistiques descriptives**

# %%
df.describe()
# Out:
#        temperature   humidite     pression  consommation
# count   599.000000  600.00000   600.000000    600.000000
# mean     24.878314   64.92620  1012.221900    208.675417
# std       4.059576   10.76905    10.599042     72.243567
# min     -18.500000   28.52000   850.000000     18.120000
# 25%      22.570000   58.17250  1006.790000    160.177500
# 50%      24.860000   65.37500  1012.855000    206.150000
# 75%      27.275000   71.61500  1017.827500    254.127500
# max      58.700000  145.00000  1038.430000    875.000000

# %% [markdown]
# # Partie 4 – Sélection

# %% [markdown]
# **1) Sélectionner la colonne "temperature"**

# %%
df["temperature"]
# Out:
# 0      25.46
# 1      24.00
# 2      25.82
# 3      28.23
# 4      20.58
#        ...
# 600    23.67
# 601    24.34
# 602    23.73
# 603    24.83
# 604    17.02
# Name: temperature, Length: 605, dtype: float64

# %% [markdown]
# **2) Sélectionner les colonnes "temperature", "humidite", "pression" et "consommation"**

# %%
df[['temperature','humidite','pression','consommation']]
# Out:
#      temperature  humidite  pression  consommation
# 0          25.46     58.06   1008.95        287.28
# 1          24.00     79.73    993.39        116.20
# 2          25.82     54.47   1010.32        288.50
# 3          28.23     69.39   1019.62        136.65
# 4          20.58     53.80   1016.58        182.62
# ..           ...       ...       ...           ...
# 600        23.67     60.28   1015.11        282.36
# 601        24.34     61.42   1019.43        357.43
# 602        23.73     63.49   1016.46        152.79
# 603        24.83     79.77   1017.05        170.97
# 604        17.02     52.04   1001.14         44.99
#
# [605 rows x 4 columns]

# %% [markdown]
# ****3) Sélectionner les 5 premières lignes avec loc
# ****
#
# loc permet de sélectionner des données en utilisant les labels de l'index et des colonnes.

# %%
df.loc[0:4]
# Out:
#   id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0     M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1     M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2     M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3     M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4     M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
#
#    pression  consommation etat
# 0   1008.95        287.28   OK
# 1    993.39        116.20   OK
# 2   1010.32        288.50   OK
# 3   1019.62        136.65   OK
# 4   1016.58        182.62   OK

# %% [markdown]
# **4) Sélectionner les 5 premières lignes et les 4 premières colonnes avec iloc
# **
#
# iloc sélectionne selon la position numérique.

# %% [markdown]
# **4) Sélectionner les 5 premières lignes et les 4 premières colonnes avec iloc**

# %%
df.iloc[0:5, 0:4]
# Out:
#   id_mesure           date_heure id_capteur batiment
# 0     M0413  2026-01-22 04:00:00       C005     B002
# 1     M0290  2026-01-17 01:00:00       C002     B001
# 2     M0077  2026-01-08 04:00:00       C005     B002
# 3     M0079  2026-01-08 06:00:00       C007     B003
# 4     M0183  2026-01-12 14:00:00       C003     B001

# %% [markdown]
# # Partie 5 – Manipulation des colonnes

# %% [markdown]
# On convertit les températures Celsius en Fahrenheit avec :
#
# F=C×9/5
# 	​
#
# +32

# %%
df["temperature_fahrenheit"] = (
    df["temperature"] * 9 / 5 + 32
)

df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
# ..        ...                  ...        ...      ...          ...       ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67     60.28
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34     61.42
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73     63.49
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83     79.77
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02     52.04
#
# ...

# %%
# verifie si bien la colonne a ete augmente
df.shape[1]
# Out:
# 10

# %% [markdown]
# On crée une nouvelle colonne en lui affectant directement une expression :
#
# df["nouvelle_colonne"] = ...
#
# Pandas applique ici le calcul à toutes les lignes automatiquement.
#
# C'est une opération vectorisée : on ne fait pas de for pour parcourir chaque température.
#
# ****2. Ajouter niveau_temperature****
#
# L'objectif est de catégoriser chaque température :
#
# L'énoncé propose where() de NumPy.

# %%
import numpy as np
df["niveau_temperature"] = np.where(
    df["temperature"]>30,
    "Élevée",
    "Normale"
)
df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  humidite  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46     58.06
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00     79.73
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82     54.47
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23     69.39
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58     53.80
# ..        ...                  ...        ...      ...          ...       ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67     60.28
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34     61.42
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73     63.49
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83     79.77
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02     52.04
#
# ...

# %% [markdown]
# **3) Renommer la colonne "humidite" en "humidite_relative"**

# %%
df = df.rename(
    columns={"humidite": "humidite_relative"}
)

df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58
# ..        ...                  ...        ...      ...          ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02
#
#      humidite_relative  pression  consommation etat  temperature_fahrenheit  \
# ...

# %% [markdown]
# La syntaxe générale est :
#
# df.rename(columns={"ancien_nom": "nouveau_nom"})
#
# Ici
#
# humidite
#    ↓
# humidite_relative
#
# Pourquoi columns= ?
#
# Parce que rename() peut également servir à renommer les index. Ici, nous indiquons explicitement que nous voulons modifier les noms des colonnes.

# %% [markdown]
# 4) Supprimer la colonne "temperature_fahrenheit"

# %%
df = df.drop(columns="temperature_fahrenheit")

df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58
# ..        ...                  ...        ...      ...          ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02
#
#      humidite_relative  pression  consommation etat niveau_temperature
# 0                58.06   1008.95        287.28   OK            Normale
# ...

# %% [markdown]
# # Partie 6 – Filtrage

# %% [markdown]
# **1) Récupérer uniquement les lignes telles que température**

# %%
df[df["temperature"] > 30]
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 7       M0132  2026-01-10 11:00:00       C012     B004        31.21
# 43      M0575  2026-01-28 22:00:00       C011     B004        34.72
# 47      M0082  2026-01-08 09:00:00       C010     B004        32.46
# 63      M0064  2026-01-07 15:00:00       C004     B002        31.19
# 79      M0275  2026-01-16 10:00:00       C011     B004        31.74
# 88      M0288  2026-01-16 23:00:00       C012     B004        30.06
# 103     M0311  2026-01-17 22:00:00       C011     B004        30.83
# 112     M0149  2026-01-11 04:00:00       C005     B002        31.46
# 118     M0365  2026-01-20 04:00:00       C005     B002        32.90
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 137     M0076  2026-01-08 03:00:00       C004     B002        31.18
# 145     M0503  2026-01-25 22:00:00       C011     B004        30.57
# 146     M0118  2026-01-09 21:00:00       C010     B004        30.32
# ...

# %% [markdown]
# **2) Récupérer uniquement les lignes telles température
#  > 30 et humidité > 70**

# %%
df[
    (df["temperature"] > 30)
    & (df["humidite_relative"] > 70)
]
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 47      M0082  2026-01-08 09:00:00       C010     B004        32.46
# 88      M0288  2026-01-16 23:00:00       C012     B004        30.06
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 145     M0503  2026-01-25 22:00:00       C011     B004        30.57
# 165     M0323  2026-01-18 10:00:00       C011     B004        33.01
# 168     M0276  2026-01-16 11:00:00       C012     B004        30.39
# 210     M0588  2026-01-29 11:00:00       C012     B004        31.51
# 251     M0114  2026-01-09 17:00:00       C006     B002        31.85
# 264     M0191  2026-01-12 22:00:00       C011     B004        30.75
# 280     M0585  2026-01-29 08:00:00       C009     B003        31.30
# 385     M0126  2026-01-10 05:00:00       C006     B002        30.09
# 398     M0514  2026-01-26 09:00:00       C010     B004        30.48
# 502     M0048  2026-01-06 23:00:00       C012     B004        58.70
# ...

# %% [markdown]
# # Partie 7 : Tri

# %% [markdown]
# 1) Créer df_trie1 pour trier en fonction de la température croissante

# %%
df_trie1 = df.sort_values(by="temperature",ascending=True)

df_trie1
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 487     M0538  2026-01-27 09:00:00       C010     B004       -18.50
# 245     M0127  2026-01-10 06:00:00       C007     B003        14.11
# 258     M0223  2026-01-14 06:00:00       C007     B003        15.49
# 249     M0175  2026-01-12 06:00:00       C007     B003        16.04
# 59      M0146  2026-01-11 01:00:00       C002     B001        16.77
# ..        ...                  ...        ...      ...          ...
# 163     M0019  2026-01-05 18:00:00       C007     B003          NaN
# 215     M0204  2026-01-13 11:00:00       C012     B004          NaN
# 513     M0490  2026-01-25 09:00:00       C010     B004          NaN
# 548     M0572  2026-01-28 19:00:00       C008     B003          NaN
# 556     M0092  2026-01-08 19:00:00       C008     B003          NaN
#
#      humidite_relative  pression  consommation    etat niveau_temperature
# 487              66.27   1012.49        312.92  ERREUR            Normale
# ...

# %% [markdown]
# **2) Créer df_trie2 pour trier en fonction de la température décroissante**

# %%
df_trie2 = df.sort_values(by="temperature",ascending=False)

df_trie2
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 502     M0048  2026-01-06 23:00:00       C012     B004        58.70
# 43      M0575  2026-01-28 22:00:00       C011     B004        34.72
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 211     M0370  2026-01-20 09:00:00       C010     B004        33.29
# 165     M0323  2026-01-18 10:00:00       C011     B004        33.01
# ..        ...                  ...        ...      ...          ...
# 163     M0019  2026-01-05 18:00:00       C007     B003          NaN
# 215     M0204  2026-01-13 11:00:00       C012     B004          NaN
# 513     M0490  2026-01-25 09:00:00       C010     B004          NaN
# 548     M0572  2026-01-28 19:00:00       C008     B003          NaN
# 556     M0092  2026-01-08 19:00:00       C008     B003          NaN
#
#      humidite_relative  pression  consommation    etat niveau_temperature
# 502              81.51   1026.79        271.92  ERREUR             Élevée
# ...

# %% [markdown]
# **3) Créer top10 pour voir les 10 températures les plus élevées**

# %%
top10 = df.sort_values(by="temperature",ascending=False).head(10)
top10
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 502     M0048  2026-01-06 23:00:00       C012     B004        58.70
# 43      M0575  2026-01-28 22:00:00       C011     B004        34.72
# 129     M0592  2026-01-29 15:00:00       C004     B002        33.60
# 211     M0370  2026-01-20 09:00:00       C010     B004        33.29
# 165     M0323  2026-01-18 10:00:00       C011     B004        33.01
# 118     M0365  2026-01-20 04:00:00       C005     B002        32.90
# 520     M0063  2026-01-07 14:00:00       C003     B001        32.72
# 438     M0558  2026-01-28 05:00:00       C006     B002        32.56
# 47      M0082  2026-01-08 09:00:00       C010     B004        32.46
# 169     M0546  2026-01-27 17:00:00       C006     B002        32.36
#
#      humidite_relative  pression  consommation    etat niveau_temperature
# 502              81.51   1026.79        271.92  ERREUR             Élevée
# ...

# %% [markdown]
# **4) Trier en fonction des colonnes "batiment" (croissant) et "temperature" (décroissant)**

# %%
df_trie_batiment = df.sort_values(
    by=["batiment", "temperature"],
    ascending=[True, False]
)

df_trie_batiment
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 520     M0063  2026-01-07 14:00:00       C003     B001        32.72
# 447     M0170  2026-01-12 01:00:00       C002     B001        31.15
# 224     M0303  2026-01-17 14:00:00       C003     B001        30.84
# 500     M0062  2026-01-07 13:00:00       C002     B001        30.39
# 9       M0087  2026-01-08 14:00:00       C003     B001        28.85
# ..        ...                  ...        ...      ...          ...
# 277     M0383  2026-01-20 22:00:00       C011     B004        20.60
# 338     M0060  2026-01-07 11:00:00       C012     B004        20.56
# 487     M0538  2026-01-27 09:00:00       C010     B004       -18.50
# 215     M0204  2026-01-13 11:00:00       C012     B004          NaN
# 513     M0490  2026-01-25 09:00:00       C010     B004          NaN
#
#      humidite_relative  pression  consommation    etat niveau_temperature
# 520              53.28   1010.05        195.37  ALERTE             Élevée
# ...

# %% [markdown]
# # Partie 8 — Analyse
#
# Ici, on utilise surtout groupby() et les fonctions d'agrégation (mean, min, max, std, sum, count).
#
# **1. Afficher la consommation moyenne par bâtiment**
#
# Concept : groupby()
#
# **groupby()** permet de regrouper les lignes selon une colonne, ici batiment

# %%
df.groupby("batiment")["consommation"].mean()
# Out:
# batiment
# B001    177.870927
# B002    221.785333
# B003    153.191000
# B004    282.552282
# Name: consommation, dtype: float64

# %% [markdown]
# **2) Afficher le minimum, le maximum, la moyenne et l’écart-type de la température par bâtiment**

# %%
df.groupby("batiment")["temperature"].agg(
    ["min", "max", "mean", "std"]
)
# Out:
#             min    max       mean       std
# batiment
# B001      16.77  32.72  23.578824  2.961211
# B002      17.67  33.60  25.778000  2.951828
# B003      14.11  31.74  23.013699  2.983902
# B004     -18.50  58.70  27.119000  5.367361

# %% [markdown]
# **3) Afficher, par bâtiment, le maximum et la moyenne de la température et de la consommation**

# %%
df.groupby("batiment").agg(
    temperature_max=("temperature", "max"),
    temperature_moyenne=("temperature", "mean"),
    consommation_max=("consommation", "max"),
    consommation_moyenne=("consommation", "mean")
)
# Out:
#           temperature_max  temperature_moyenne  consommation_max  \
# batiment
# B001                32.72            23.578824            294.72
# B002                33.60            25.778000            335.20
# B003                31.74            23.013699            875.00
# B004                58.70            27.119000            411.12
#
#           consommation_moyenne
# batiment
# B001                177.870927
# B002                221.785333
# B003                153.191000
# B004                282.552282

# %% [markdown]
# 4. Afficher la température moyenne globale
#
# Ici, on ne regroupe plus par bâtiment.

# %%
df["temperature"].mean()
# Out:
# np.float64(24.87831385642738)

# %% [markdown]
# **5) Afficher la température maximale**

# %%
df["temperature"].max()
# Out:
# np.float64(58.7)

# %% [markdown]
# **6) Afficher la consommation totale**

# %%
df["consommation"].sum()
# Out:
# np.float64(125205.25)

# %% [markdown]
# **7) Quel bâtiment consomme le plus en moyenne ?**

# %% [markdown]
# **7) Quel bâtiment consomme le plus en moyenne ?**

# %%
consommation_moyenne = (
    df.groupby("batiment")["consommation"]
    .mean()
)

consommation_moyenne
# Out:
# batiment
# B001    177.870927
# B002    221.785333
# B003    153.191000
# B004    282.552282
# Name: consommation, dtype: float64

# %%
consommation_moyenne.idxmax()
print(
    f"Le bâtiment qui consomme le plus en moyenne est "
    f"{consommation_moyenne.idxmax()} "
    f"avec {consommation_moyenne.max():.2f}."
)
# Out:
# Le bâtiment qui consomme le plus en moyenne est B004 avec 282.55.

# %% [markdown]
# **8) Afficher le nombre d'alertes par bâtiment**

# %%
df["etat"].value_counts()
# Out:
# etat
# OK        567
# ALERTE     29
# ERREUR      5
# Name: count, dtype: int64

# %%
alertes_par_batiment = (
    df[df["etat"] == "ALERTE"]
    .groupby("batiment")
    .size()
    .rename("nombre_alertes")
)

alertes_par_batiment
# Out:
# batiment
# B001     2
# B002     7
# B003     5
# B004    15
# Name: nombre_alertes, dtype: int64

# %% [markdown]
# **Partie 9 — Gestion des valeurs manquantes**
#
# On commence par comprendre chaque commande, puis on l'applique au TP.
#
# 1. Afficher le nombre de valeurs manquantes par colonne

# %%
df.isna().sum()
# Out:
# id_mesure             0
# date_heure            0
# id_capteur            0
# batiment              0
# temperature           6
# humidite_relative     5
# pression              5
# consommation          5
# etat                  4
# niveau_temperature    0
# dtype: int64

# %% [markdown]
# **2. Afficher le nombre total de valeurs manquantes**
#
# On reprend isna() et sum(), mais on ajoute un deuxième sum() :

# %%
df.isna().sum().sum()
# Out:
# np.int64(25)

# %% [markdown]
# **3) Afficher le taux de valeurs manquantes**
#
# On veut le pourcentage de valeurs manquantes par colonne.

# %%
df.isna().mean() * 100
# Out:
# id_mesure             0.000000
# date_heure            0.000000
# id_capteur            0.000000
# batiment              0.000000
# temperature           0.991736
# humidite_relative     0.826446
# pression              0.826446
# consommation          0.826446
# etat                  0.661157
# niveau_temperature    0.000000
# dtype: float64

# %% [markdown]
# **4) Afficher les lignes contenant des valeurs manquantes**

# %%
df[df.isna().any(axis=1)]
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 14      M0056  2026-01-07 07:00:00       C008     B003        22.33
# 30      M0073  2026-01-08 00:00:00       C001     B001        23.12
# 91      M0473  2026-01-24 16:00:00       C005     B002        21.32
# 128     M0300  2026-01-17 11:00:00       C012     B004        23.32
# 139     M0345  2026-01-19 08:00:00       C009     B003          NaN
# 146     M0118  2026-01-09 21:00:00       C010     B004        30.32
# 149     M0034  2026-01-06 09:00:00       C010     B004        28.91
# 163     M0019  2026-01-05 18:00:00       C007     B003          NaN
# 196     M0372  2026-01-20 11:00:00       C012     B004        29.33
# 215     M0204  2026-01-13 11:00:00       C012     B004          NaN
# 270     M0334  2026-01-18 21:00:00       C010     B004        29.63
# 303     M0584  2026-01-29 07:00:00       C008     B003        23.78
# 307     M0169  2026-01-12 00:00:00       C001     B001        21.86
# ...

# %% [markdown]
# **5. Remplacer les valeurs manquantes de temperature et humidite par les moyennes**

# %%
df["temperature"].mean() # la moyenne  de la temperature
# Out:
# np.float64(24.87831385642738)

# %%
df["humidite_relative"].mean() # La moyenne de humidite
# Out:
# np.float64(64.92620000000001)

# %%
df["temperature"] = df["temperature"].fillna(
    df["temperature"].mean()
)

df["humidite_relative"] = df["humidite_relative"].fillna(
    df["humidite_relative"].mean()
)
df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58
# ..        ...                  ...        ...      ...          ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02
#
#      humidite_relative  pression  consommation etat niveau_temperature
# 0                58.06   1008.95        287.28   OK            Normale
# ...

# %% [markdown]
# **6. Remplacer les valeurs manquantes de consommation par la médiane**
#
# On calcule d'abord la médiane :

# %%
df["consommation"].median()
# Out:
# np.float64(206.14999999999998)

# %%
df["consommation"].median()
# Out:
# np.float64(206.14999999999998)

# %%
df["consommation"] = df["consommation"].fillna(
    df["consommation"].median()
)
df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58
# ..        ...                  ...        ...      ...          ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02
#
#      humidite_relative  pression  consommation etat niveau_temperature
# 0                58.06   1008.95        287.28   OK            Normale
# ...

# %% [markdown]
# **7. Remplacer les valeurs manquantes de etat par "INCONNU"**

# %%
df["etat"] = df["etat"].fillna("INCONNU")
df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58
# ..        ...                  ...        ...      ...          ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02
#
#      humidite_relative  pression  consommation etat niveau_temperature
# 0                58.06   1008.95        287.28   OK            Normale
# ...

# %% [markdown]
# On évite ainsi de perdre ces observations simplement parce que leur état n'a pas été renseigné.

# %% [markdown]
# # Partie 10 : Gestion des doublons

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 600    False
# 601    False
# 602    False
# 603    False
# 604    False
# Length: 605, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df[df.duplicated()]
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 183     M0599  2026-01-29 22:00:00       C011     B004        22.02
# 231     M0026  2026-01-06 01:00:00       C002     B001        22.87
# 355     M0147  2026-01-11 02:00:00       C003     B001        26.14
# 538     M0456  2026-01-23 23:00:00       C012     B004        20.68
# 539     M0302  2026-01-17 13:00:00       C002     B001        22.05
#
#      humidite_relative  pression  consommation etat niveau_temperature
# 183              68.09   1005.90        227.81   OK            Normale
# 231              77.99   1010.15        213.19   OK            Normale
# 355              84.97   1003.59        142.31   OK            Normale
# 538              72.69   1022.77        309.01   OK            Normale
# 539              58.26   1007.30        140.42   OK            Normale

# %% [markdown]
# **10. Supprimer les doublons puis vérifier**
#
# On utilise drop_duplicates() :

# %%
df = df.drop_duplicates()
df
# Out:
#     id_mesure           date_heure id_capteur batiment  temperature  \
# 0       M0413  2026-01-22 04:00:00       C005     B002        25.46
# 1       M0290  2026-01-17 01:00:00       C002     B001        24.00
# 2       M0077  2026-01-08 04:00:00       C005     B002        25.82
# 3       M0079  2026-01-08 06:00:00       C007     B003        28.23
# 4       M0183  2026-01-12 14:00:00       C003     B001        20.58
# ..        ...                  ...        ...      ...          ...
# 600     M0072  2026-01-07 23:00:00       C012     B004        23.67
# 601     M0107  2026-01-09 10:00:00       C011     B004        24.34
# 602     M0271  2026-01-16 06:00:00       C007     B003        23.73
# 603     M0436  2026-01-23 03:00:00       C004     B002        24.83
# 604     M0103  2026-01-09 06:00:00       C007     B003        17.02
#
#      humidite_relative  pression  consommation etat niveau_temperature
# 0                58.06   1008.95        287.28   OK            Normale
# ...

# %% [markdown]
# Cette commande retourne un DataFrame dans lequel les doublons ont été supprimés.
#
# Ensuite, on vérifie :
